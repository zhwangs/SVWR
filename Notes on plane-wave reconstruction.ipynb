# %% [markdown]
# # Plane wave reconstruction and Error analysis
#
# ***
# Plane wave reconstruction has two important factors:
#  - Wavevector magnitude
# ```python
# kk=0.01
# K=kk*np.array([1,0,-1])
# K_mag=np.sqrt(np.sum(K**2))
# ```
#  - geometry size
# ```python
# rad_test=100
# ```
# The radial function (Bessel function) takes the variable, kr, and it controls the reconstrction accuracy. In general, a smaller kr will give more accurate result.
#
#
# ## Plane Wave generation: SVW_ver1/test/Exp/Plane_wave_rec_test.py
# The following figures show the electric field magnitude in three cartesian components (x,y,z). The red arrow indicates the direction of the wavevector, the green arrow indicates the current state of polarization, and the two blue arrow shows the local cartesian basis for that particular polarization above ($\vec{e_a}$, $\vec{e_b}$). The reconstruction plane wave is compared against the generated plane wave.
#
# ### Inputs:
#  - Wavevector $\vec{k_e}$ and magnitude
# ```python
# kk=0.01
# K=kk*np.array([1,0,-1])
# K_mag=np.sqrt(np.sum(K**2))
# ```
# <br>
#  - Orientation angle: polar_psi $\psi \in [0,\pi)$
# ```python
# polar_psi=pi/4
# ```
# <br>
#  - Ellipticity angle: polar_chi $\chi \in [-\frac{\pi}{4},\frac{\pi}{4}]$
# ```python
# polar_chi=0
# ```
# <br>
#  - Electric Field Strength: $E_0$
# ```python
# E0=1
# ```
# <br>
#
#  - geometry size
# ```python
# rad_test=100
# ```
#  - n_max
# ```python
# n_max=6
# ```
#
# ## Reconstruction: Sphere, Linear polaized field in [1,0,-1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#  ![201.png](image/201.png)
# ## Generation: Sphere, Linear polaized field in [1,0,-1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#  ![202.png](image/202.png)
#
#
# ## Error Analysis: SVW_ver1/test/Exp/Error_map_K.py
# The following calculates the mean square error (MSE) between generated electric field and reconstruction electric field for a particular set of variables from above. The output returns the following:
#
# ```python
# print(Error_x,Error_y,Error_z)
#
# ```
#
# ## 3D K uniform direction mapping:
# This error map calculates the ralative error for all given wavevector directions with a fixed geometry size and wavevector magnitude.
# ![203.png](image/203.png)
#
# ##  2D K-R span mapping
# This error map calculates the ralative error in a span of geometry sizes and wavevector magnitude, with a fixed wavevector direction.
#
# ![204.png](image/204.png)
