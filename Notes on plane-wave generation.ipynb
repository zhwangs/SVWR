# %% [markdown]
# ## Plane wave notation and polarizations
#
# ### Plane wave:
#  <center>
#     $ \vec{E}(\vec{r})=\vec{E_{0}}e^{i\vec{k_e}\cdot\vec{r}} $
#  </center>
#  and
#   <center>
#     $ \vec{H}(\vec{r})=\sqrt{\frac{\varepsilon}{\mu}}\vec{e_k} \times \vec{E}(r)  $
#  </center>
#
# ### Basis constructions:
# From the lab basis {$e_x$,$e_y$,$e_z$}, we can constract a set of {$e_k$,$e_a$,$e_b$} by two angles (a$\phi$, b$\theta$) for the following,
#
#  <center>
#     $ e_k=sin(b)cos(a)\vec{e_x} +sin(b)sin(a)\vec{e_y}+cos(b)\vec{e_z}\\
#     e_b=cos(b)sin(a)\vec{e_x} +cos(b)sin(a)\vec{e_y}-sin(b)\vec{e_z}\\
#      e_a=-sin(a)\vec{e_x} +cos(a)\vec{e_y}\\$
#
#  </center>
#
# By considering a plane wave with arbitrary isotropic media, direction and polarizations:
#  where the E-field can be expressed as the following:
#  <center>
#     $ \vec{E}(\vec{r})=\vec{E_{0}}e^{i\vec{k_e}\cdot\vec{r}} $
#  </center>
#  Where
#  <center>
#     $ \vec{E}(\vec{r})=E_{a}\vec{e_a}+E_{b}\vec{e_b} $
#  </center>
#  Then, respects to the basis, any polarization can be expressed as two angles $\psi$ and $\chi$ in a vibration ellipse[1].$\\[0.5cm]$
#
#   <center>
#     $ E_{a}=E_{0}(cos\chi sin\psi-isin\chi cos\psi) $
#  </center>
#  and
#    <center>
#     $ E_{b}=E_{0}(cos\chi sin\psi+isin\chi cos\psi) $
#  </center>
#
#
# ***
# ## Examples:
#
# ### Plane Wave generation: SVW_ver1/test/Exp/Plane_wave_test.py
# The following figures show the electric field magnitude in three cartesian components (x,y,z). The red arrow indicates the direction of the wavevector, the green arrow indicates the current state of polarization, and the two blue arrow shows the local cartesian basis for that particular polarization above ($\vec{e_a}$, $\vec{e_b}$).
#
# #### Inputs:
#  - Wavevector $\vec{k_e}$ and magnitude
# ```python
# kk=0.1
# K=kk*np.array([1,0,-1])
# K_mag=np.sqrt(np.sum(K**2))
# ```
# <br>
#  - Orientation angle: polar_psi $\psi \in [0,\pi)$
# ```python
# polar_psi=pi/4
# ```
# <br>
#  - Ellipticity angle: polar_chi $\chi \in [-\frac{\pi}{4},\frac{\pi}{4}]$
# ```python
# polar_chi=0
# ```
# <br>
#  - Electric Field Strength: $E_0$
# ```python
# E0=1
# ```
# <br>
#  - Time: $t_0$
# ```python
# t_0=0
# ```
#
#
# #### Note:
# Currently, around the wavevector direction [0,1,1], there are slightly larger error in display. But there should not be difference in the field generation.
#
#
# ### Sphere, Linear polaized field in [1,0,-1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#
# ![101.png](image/101.png)
#
# ### Sphere, Linear polaized field in [1,1,1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#
# ![102.png](image/102.png)
#
# ### Sphere, Linear polaized field in [1,1,1] direction, Orientation angle: 0, Ellipticity angle: 0
# #### Note: there is no x component since it is polarized in x direction
# ![103.png](image/103.png)
#
# ### Sphere, Linear polaized field in [1,1,1] direction, Orientation angle: 0, Ellipticity angle: pi/3
# ![104.png](image/104.png)
#
# ### Cube, Linear polaized field in [1,0,-1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#
# ![105.png](image/105.png)
# ### Cube, Linear polaized field in [1,1,1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#
# ![106.png](image/106.png)
#
# ### Prism, Linear polaized field in [1,0,-1] direction, Orientation angle: pi/4, Ellipticity angle: 0
#
# ![107.png](image/10.png)
